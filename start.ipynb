# %%
from google.colab import drive
drive.mount('/content/drive')

# kaggle is the folder that I created on my drive
# !cd "drive/My Drive/object_pose_estimation"

# Downloading the repo on my drive
# !git clone https://github.com/MatthiasDR96/object_pose_estimation_online.git
# Out:
# Mounted at /content/drive
# Cloning into 'object_pose_estimation_online'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 95 (delta 12), reused 93 (delta 10), pack-reused 0
# Unpacking objects: 100% (95/95), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
