# %%
import sys
sys.path.append('/content/drive/My Drive/object_pose_estimation')
from Classes.Visualization import *

# %%
# Robot position in joint space
pos = [0, 0, 0, 0, 0, 0]

# %%
# Visualize transform
visualize(pos)
# Out:
# Baselink-target transform...
#
# [[ 0.57942635 -0.8081212   0.1051796   0.02095953]
#  [-0.80202214 -0.58834008 -0.10255195 -0.65825655]
#  [ 0.14471807 -0.02493364 -0.98904676 -0.0438513 ]
#  [ 0.          0.          0.          1.        ]]
#
# Baselink-object transform...
#
# [[ 0.64767659 -0.76065206  0.04220186  0.02084259]
#  [-0.75499469 -0.64824758 -0.09827797 -0.71689142]
#  [ 0.10207422  0.03178913 -0.99415734  0.00188025]
#  [ 0.          0.          0.          1.        ]]
#
# Baselink-grasp transform...
#
# [[ 0.64767659 -0.76065206  0.04220186  0.01929005]
#  [-0.75499469 -0.64824758 -0.09827797 -0.7694288 ]
#  [ 0.10207422  0.03178913 -0.99415734  0.30870315]
#  [ 0.          0.          0.          1.        ]]
