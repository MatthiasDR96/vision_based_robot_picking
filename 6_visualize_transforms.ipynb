# %% [markdown]
# # Visualiseren van de transformaties
#
# > Alle transformatiematrices die je tot hiertoe hebt berekend kan je hier visualiseren. Dit is zowel de ${}^{B}T_{C}$ alsook de ${}^{B}T_{T}$ transformatie. Ook zal de robot zelf geplot worden. Je zal dus een visualisatie krijgen van de robot met de camera en het object, allen in dezelfde ruimte en in hetzelfde frame. Zoals je ze hier zal zien, liggen ze dus ook fysiek in de ruimte.

# %% [markdown]
# # 1. Importeer bibliotheken
#
# > Deze bibliotheken zijn nodig voor het volbrengen van dit script. In de CameraCalibration bibliotheek vind je de code achter de commando's die je hier zal gebruiken.

# %%
import sys
from math import *
sys.path.append('/content/drive/My Drive/object_pose_estimation_online')
from Classes.Visualization import *

# %% [markdown]
# # 2. Visialiseer robot en frames
#
# > Deze functie print de baselink-end effector, baselink-camera, en baselink-target matrices uit en plot deze ook samen met de robot frames. In de variabele 'pos' kan je gewenste joint variabelen ingeven voor de robot. Deze zal dan geplot worden volgens deze configuratie.

# %%
# Robot position in joint space
pos = [-pi/2, 0, 0, 0, 0, 0]

# %%
# Visualize transform
visualize(pos)

# %% [markdown]
# > Je kan hier wat met de joint variabelen spelen om de robot in verschillende posities te plotten.
