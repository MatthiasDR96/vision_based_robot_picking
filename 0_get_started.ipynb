# %% [markdown]
# # Setup working environment
#
# Om gemakkelijk met alle scripts te kunnen werken en de data op de juiste locatie te hebben zal dit script linken met je persoonlijke Google Drive en alle nodige software en data vanop GitHub laden in je Google Drive. In de volgende scripts kan je dan telkens linken met je Google Drive om de scripts te kunnen uitvoeren.

# %%
# Mount Google drive to Google Colab
from google.colab import drive
drive.mount('/content/drive')

# %%
# Go to My Drive folder
# %cd drive/My\ Drive

# %%
# Download github package
# !git clone https://github.com/MatthiasDR96/object_pose_estimation_online.git
