# %% [markdown]
# 1. Setup working environment

# %%
# Mount Google drive to Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Go to My Drive folder
# %cd drive/My\ Drive
# Out:
# /content/drive/My Drive

# %%
# Download github package 
# !git clone https://github.com/MatthiasDR96/object_pose_estimation_online.git
# Out:
# fatal: destination path 'object_pose_estimation_online' already exists and is not an empty directory.
