# %%
import cv2
import imutils
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('/content/drive/My Drive/object_pose_estimation_online/data/robot_target_calibration_images/RTC_image_original_1.jpg')

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
canny = cv2.Canny(gray_image, 200, 300)
canny = cv2.erode(canny)
cv2_imshow(canny)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-0f4e56be14f5> in <module>()
#       1 canny = cv2.Canny(gray_image, 200, 300)
# ----> 2 canny = cv2.erode(canny)
#       3 cv2_imshow(canny)
#
# TypeError: Required argument 'kernel' (pos 2) not found

# %%
contours = cv2.findContours(canny, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(contours)

# %%
with_contours = cv2.drawContours(image.copy(), contours, -1, (0, 255, 0), 3)

# %%
plt.imshow(image)
plt.figure()
plt.imshow(with_contours)
plt.show()
